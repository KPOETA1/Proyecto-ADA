# %%
import seaborn as sns
import pandas as pd
import numpy as np
from Punto2 import *
from Autogenerador import *

import time

# %%
def prueba_casos(path):
    data = pd.DataFrame(columns=['n_palabras', 'tiempo'])

    for i in range(100000, 1000001, 200000):
        generar_problema(i)
        start = time.time()
        resolver()
        end = time.time()
        data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)

    data.to_csv(path, index=False)

# %%
prueba_casos()

# %%
data = pd.read_csv('tiempos.csv')
data.head()
# Out:
#    n_palabras    tiempo
# 0     10000.0  0.154318
# 1     20000.0  0.323996
# 2     30000.0  0.509801
# 3     40000.0  0.704669
# 4     50000.0  0.858038

# %%
sns.lineplot(x='n_palabras', y='tiempo', data=data)
# Out:
# <AxesSubplot: xlabel='n_palabras', ylabel='tiempo'>

# %%
prueba_casos('tiempos3.csv')
# Out:
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1731579629.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1731579629.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1731579629.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# ...

# %%
data2 = pd.read_csv('tiempos2.csv')
sns.lineplot(x='n_palabras', y='tiempo', data=data2)
# Out:
# <AxesSubplot: xlabel='n_palabras', ylabel='tiempo'>

# %%
data3 = pd.read_csv('tiempos3.csv')
sns.lineplot(x='n_palabras', y='tiempo', data=data3)
# Out:
# <AxesSubplot: xlabel='n_palabras', ylabel='tiempo'>

# %%
prueba_casos('tiempos4.csv')
# Out:
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1930066936.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1930066936.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\1930066936.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# ...

# %%
data4 = pd.read_csv('tiempos4.csv')
sns.lineplot(x='n_palabras', y='tiempo', data=data4)
# Out:
# <AxesSubplot: xlabel='n_palabras', ylabel='tiempo'>

# %%
prueba_casos('tiempos5.csv')
data5 = pd.read_csv('tiempos5.csv')
sns.lineplot(x='n_palabras', y='tiempo', data=data5)
# Out:
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\3691549177.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\3691549177.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\3691549177.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# ...

# %%
prueba_casos('tiempos6.csv')
data5 = pd.read_csv('tiempos6.csv')
sns.lineplot(x='n_palabras', y='tiempo', data=data6)
# Out:
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\4103936423.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\4103936423.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# C:\Users\ARAGANA\AppData\Local\Temp\ipykernel_18284\4103936423.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({'n_palabras': i, 'tiempo': end - start}, ignore_index=True)
# ...
